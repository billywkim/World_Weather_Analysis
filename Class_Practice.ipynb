# %%
# Dependencies
import requests
import json

# Google developer API key
from config import g_key

# %%
# geocoordinates
target_coordinates = "30.267153, -97.7430608" # Austin Lat, Lon
target_search = "Chinese" 
target_radius = 8000 # meters = 4.97 miles
target_type = "restaurant"

# set up a parameters dictionary
params_for_google = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params_for_google)

# %%
response
# Out:
# <Response [200]>

# %%
places_data = response.json()
places_data
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AeJbb3fTvrXaagOP1FtfX8lsb-qzgglUEtpopt9RZB963J3WY9qk5MzRQPBho6gRDQetmUmGzQtW1dApyAQ3opMkwecxr4mXvjN904wZ7ybcrJMRs37JOON3JlYZlq6rzaNFf5ANBhdzrT46QRfmLat_x2aXZLGh9m1HBjMsKedLSq1z-yz_0TJIR4cERsw2mycqXZFbihM-pNIsb0g7IvjDNf8-FDccLcWkKGAp3aIVcqs8VxHHWH6EnU0Vn11sfKwj7SyDlq7ucqOSLKnSO1gcD7Vs7r3R2rg2kQ0_EvuEg43j3BEJtdkrHSyuwYJcY7MBk4XOfAZg32iYdRI1T3r8q95K8MGIJV1H6HXPU14xSoanlcuXOADZJINhLvfn3Y1f9VBDBm7pO5jgqRT4QisIpUhr5kuDie-vT6BtsDObbo3BhDZtXbFBCZxyoRhqVyW2gxSWVGjr',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 30.2257869, 'lng': -97.7711758},
#     'viewport': {'northeast': {'lat': 30.22724152989272,
#       'lng': -97.76974337010728},
#      'southwest': {'lat': 30.22454187010728, 'lng': -97.77244302989273}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
# ...

# %%
# Print the json (pretty printed)
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "AeJbb3fTvrXaagOP1FtfX8lsb-qzgglUEtpopt9RZB963J3WY9qk5MzRQPBho6gRDQetmUmGzQtW1dApyAQ3opMkwecxr4mXvjN904wZ7ybcrJMRs37JOON3JlYZlq6rzaNFf5ANBhdzrT46QRfmLat_x2aXZLGh9m1HBjMsKedLSq1z-yz_0TJIR4cERsw2mycqXZFbihM-pNIsb0g7IvjDNf8-FDccLcWkKGAp3aIVcqs8VxHHWH6EnU0Vn11sfKwj7SyDlq7ucqOSLKnSO1gcD7Vs7r3R2rg2kQ0_EvuEg43j3BEJtdkrHSyuwYJcY7MBk4XOfAZg32iYdRI1T3r8q95K8MGIJV1H6HXPU14xSoanlcuXOADZJINhLvfn3Y1f9VBDBm7pO5jgqRT4QisIpUhr5kuDie-vT6BtsDObbo3BhDZtXbFBCZxyoRhqVyW2gxSWVGjr",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 30.2257869,
#                     "lng": -97.7711758
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.22724152989272,
#                         "lng": -97.76974337010728
#                     },
# ...

# %%
# Number of restaurants returned
len(places_data["results"])
# Out:
# 20

# %%
places_data["results"][0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 30.2257869, 'lng': -97.7711758},
#   'viewport': {'northeast': {'lat': 30.22724152989272,
#     'lng': -97.76974337010728},
#    'southwest': {'lat': 30.22454187010728, 'lng': -97.77244302989273}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#  'icon_background_color': '#FF9E67',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'name': 'Bamboo Garden Chinese Restaurant',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 4032,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115229353425844833429">Blanca Mendez-Salgado</a>'],
#    'photo_reference': 'AeJbb3d2jzAfjKXd739RBsj3qu6ajv-VVTv5D3iTIX14Vv4pvRyVrEgy65_te7dOe3vyCOxBUVtkULnrlB7yGnqCLs1uzLh2bP-aUt-mWWo74SG_BkzeuNSo-_Q2T660C-ipn_Iqhxoz3EiyLzGy_SzxIDl48v3O6kUKt8CmgsZBIzk1xQuO',
#    'width': 3024}],
# ...

# %%
print(places_data["results"][0]["name"])
print(places_data["results"][0]["vicinity"])
# Out:
# Bamboo Garden Chinese Restaurant
# 625 W Ben White Blvd, Austin

# %%
places_data["results"][0]
# Out:
# {'business_status': 'OPERATIONAL',
#  'geometry': {'location': {'lat': 30.2257869, 'lng': -97.7711758},
#   'viewport': {'northeast': {'lat': 30.22724152989272,
#     'lng': -97.76974337010728},
#    'southwest': {'lat': 30.22454187010728, 'lng': -97.77244302989273}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#  'icon_background_color': '#FF9E67',
#  'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#  'name': 'Bamboo Garden Chinese Restaurant',
#  'opening_hours': {'open_now': True},
#  'photos': [{'height': 4032,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115229353425844833429">Blanca Mendez-Salgado</a>'],
#    'photo_reference': 'AeJbb3d2jzAfjKXd739RBsj3qu6ajv-VVTv5D3iTIX14Vv4pvRyVrEgy65_te7dOe3vyCOxBUVtkULnrlB7yGnqCLs1uzLh2bP-aUt-mWWo74SG_BkzeuNSo-_Q2T660C-ipn_Iqhxoz3EiyLzGy_SzxIDl48v3O6kUKt8CmgsZBIzk1xQuO',
#    'width': 3024}],
# ...
